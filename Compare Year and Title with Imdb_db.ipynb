# %%
import pandas as pd

# %%
combined_df = pd.read_csv('./Year_Released Title and Metacritic Rating.csv')
imdb_db = pd.read_csv('./imdb_db.csv')

# %%
imdb_db = imdb_db[['primaryTitle','averageRating','startYear']]
imdb_db = pd.DataFrame(imdb_db)
imdb_db.columns = ['Title','Imdb Rating','Year']

# %%
combined_df = combined_df.loc[combined_df['Year'] != 'TBA']
# Out:
# C:\Users\ Derek\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
combined = pd.merge(combined_df,imdb_db,how='inner',on = 'Title')

# %%
combined['Year_x'] = combined['Year_x'].astype(int)
combined['Year_y'] = combined['Year_y'].astype(int)

# %%
combined = combined[combined['Year_x'] == combined['Year_y']]

# %%
combined = combined.drop(columns ='Year_y')
combined.columns = ['Title','Year','Metacritic Rating','Netflix','Amazon','Hulu','Imdb Rating']
combined.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-182797a09044> in <module>
# ----> 1 combined = combined.drop(columns ='Year_y')
#       2 combined.columns = ['Title','Year','Metacritic Rating','Netflix','Amazon','Hulu','Imdb Rating']
#       3 combined.head()
#
# ~\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# ~\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['Year_y'] not found in axis"

# %%
# Out:
#                                                   Title  Year_x  \
# 0                                          Citizen Kane    1941
# 1                                         The Godfather    1972
# 2                                           Rear Window    1954
# 6                                               Boyhood    2014
# 7                                     Three Colors: Red    1994
# 8                                               Vertigo    1958
# 9                                             Notorious    1946
# 11                                  Singin' in the Rain    1952
# 14                                            Moonlight    2016
# 15                                            Pinocchio    1940
# 24                                        Touch of Evil    1958
# 25                     The Treasure of the Sierra Madre    1948
# 26                                      Pan's Labyrinth    2006
# 27                                   North by Northwest    1959
# 28                                        All About Eve    1950
# 29                                          Hoop Dreams    1994
# 31                                        The Third Man    1949
# 32    Dr. Strangelove or: How I Learned to Stop Worr...    1964
# 37                                     Some Like It Hot    1959
# 39                                               Psycho    1960
# 43                                    American Graffiti    1973
# 45                                                Dumbo    1941
# 49                                                 Roma    2018
# 50                                                  Ran    1985
# 51                                         12 Angry Men    1957
# 52                                Manchester by the Sea    2016
# 53                                      Rosemary's Baby    1968
# 56                                   The Maltese Falcon    1941
# 57                                     12 Years a Slave    2013
# 58                                            Nashville    1975
# ...                                                 ...     ...
# 1497                                    The Hate U Give    2018
# 1498                                        At Berkeley    2013
# 1499                                  Blade Runner 2049    2017
# 1500                                               Step    2017
# 1501                                       Experimenter    2015
# 1513               The Revolution Will Not Be Televised    2003
# 1514                              A History of Violence    2005
# 1515                                      A Mighty Wind    2003
# 1516                                  The Damned United    2009
# 1518                                            Georgia    1995
# 1520                                              Fresh    1994
# 1523                                            Arrival    2016
# 1525                                               Juno    2007
# 1526                                     Blue Valentine    2010
# 1528    Master and Commander: The Far Side of the World    2003
# 1529                        Four Weddings and a Funeral    1994
# 1531                                           Top Five    2014
# 1532                     Pete Seeger: The Power of Song    2007
# 1539                                 Living in Oblivion    1995
# 1541                                               Coco    2017
# 1542                                               Coco    2017
# 1544                                    Bridge of Spies    2015
# 1545                                 Driving Miss Daisy    1989
# 1547                              Shaun the Sheep Movie    2015
# 1549                                  The Station Agent    2003
# 1550                                         Foxcatcher    2014
# 1554                                            Dolores    2017
# 1555                                          Twinsters    2015
# 1559                                 The China Syndrome    1979
# 1560                                        Bright Star    2009
#
#       Metacritic Rating  Netflix  Amazon  Hulu  Imdb Rating
# 0                   100      NaN     NaN   NaN          8.3
# 1                   100      NaN     NaN   NaN          9.2
# 2                   100      NaN     NaN   NaN          8.5
# 6                   100      NaN     NaN   NaN          7.9
# 7                   100      NaN     NaN   NaN          8.1
# 8                   100      NaN     NaN   NaN          8.3
# 9                   100      NaN     NaN   NaN          8.0
# 11                  100      NaN     NaN   NaN          8.3
# 14                  100      NaN     NaN   NaN          7.4
# 15                  100      NaN     NaN   NaN          7.5
# 24                  100      NaN     NaN   NaN          8.0
# 25                  100      NaN     NaN   NaN          8.2
# 26                  100      NaN     NaN   NaN          8.2
# 27                  100      NaN     NaN   NaN          8.3
# 28                  100      NaN     NaN   NaN          8.3
# 29                   99      NaN     NaN   NaN          8.3
# 31                   99      NaN     NaN   NaN          8.2
# 32                   99      NaN     NaN   NaN          8.4
# 37                   99      NaN     NaN   NaN          8.2
# 39                   99      NaN     NaN   NaN          8.5
# 43                   98      NaN     NaN   NaN          7.5
# 45                   98      NaN     NaN   NaN          7.3
# 49                   98      NaN     NaN   NaN          7.8
# 50                   98      NaN     NaN   NaN          8.2
# 51                   98      NaN     NaN   NaN          8.9
# 52                   98      NaN     NaN   NaN          7.8
# 53                   98      NaN     NaN   NaN          8.0
# 56                   98      NaN     NaN   NaN          8.1
# 57                   98      NaN     NaN   NaN          8.1
# 58                   98      NaN     NaN   NaN          7.8
# ...                 ...      ...     ...   ...          ...
# 1497                 86      NaN     NaN   NaN          7.3
# 1498                 86      NaN     NaN   NaN          7.3
# 1499                 86      NaN     NaN   NaN          8.0
# 1500                 86      NaN     NaN   NaN          6.8
# 1501                 86      NaN     NaN   NaN          6.6
# 1513                 86      NaN     NaN   NaN          8.4
# 1514                 86      NaN     NaN   NaN          7.5
# 1515                 86      NaN     NaN   NaN          7.3
# 1516                 86      NaN     NaN   NaN          7.6
# 1518                 86      NaN     NaN   NaN          6.5
# 1520                 86      NaN     NaN   NaN          7.6
# 1523                 86      NaN     NaN   NaN          7.9
# 1525                 86      NaN     NaN   NaN          7.5
# 1526                 86      NaN     NaN   NaN          7.4
# 1528                 86      NaN     NaN   NaN          7.4
# 1529                 86      NaN     NaN   NaN          7.1
# 1531                 86      NaN     NaN   NaN          6.4
# 1532                 86      NaN     NaN   NaN          8.3
# 1539                 86      NaN     NaN   NaN          7.5
# 1541                 86      NaN     NaN   NaN          8.4
# 1542                 86      NaN     NaN   NaN          7.4
# 1544                 86      NaN     NaN   NaN          7.6
# 1545                 86      NaN     NaN   NaN          7.4
# 1547                 86      NaN     NaN   NaN          7.4
# 1549                 85      NaN     NaN   NaN          7.7
# 1550                 85      NaN     NaN   NaN          7.0
# 1554                 85      NaN     NaN   NaN          7.0
# 1555                 85      NaN     NaN   NaN          7.6
# 1559                 85      NaN     NaN   NaN          7.4
# 1560                 85      NaN     NaN   NaN          7.0
#
# [645 rows x 7 columns]
